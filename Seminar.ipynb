# %% [markdown]
# <a href="https://colab.research.google.com/github/AInitikesh/Seminar/blob/main/Seminar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = [10, 10]

# %% [markdown]
# # Classification
#
# **Acceptance in university**

# %%
# Grades , Test
student_1 = (8,9)
student_2 = (4,3)
student_3 = (6,7)
plt.xlim((0, 10))
plt.ylim((0, 10))
plt.xlabel("GRADES")
plt.ylabel("TEST")
s1_plot = plt.scatter(*student_1, marker='^', color=['green'], s=100)
s2_plot = plt.scatter(*student_2, marker='^', color=['red'], s=100)
s3_plot = plt.scatter(*student_3, marker='^', color=['blue'], s=100)
plt.legend((s1_plot, s2_plot, s3_plot), ("Student 1(GRADES - 8, TEST - 9) Accepted", "Student 2(GRADES - 4, TEST - 3) Rejected ", "Student 3(GRADES - 6, TEST - 7) ? "))
plt.plot([student_1[0], 0], [student_1[1], student_1[1]], color='black', linestyle = 'dashed')
plt.plot([student_1[0], student_1[0]], [student_1[1], 0], color='black', linestyle = 'dashed')

plt.plot([student_2[0], 0], [student_2[1], student_2[1]], color='black', linestyle = 'dashed')
plt.plot([student_2[0], student_2[0]], [student_2[1], 0], color='black', linestyle = 'dashed')
plt.show()

# %%
plt.xlim((0, 10))
plt.ylim((0, 10))
plt.xlabel("GRADES")
plt.ylabel("TEST")
s1_plot = plt.scatter(*student_1, marker='^', color=['green'], s=100)
s2_plot = plt.scatter(*student_2, marker='^', color=['red'], s=100)
s3_plot = plt.scatter(*student_3, marker='^', color=['blue'], s=100)
plt.legend((s1_plot, s2_plot, s3_plot), ("Student 1(GRADES - 8, TEST - 9) Accepted", "Student 2(GRADES - 4, TEST - 3) Rejected", "Student 3(GRADES - 6, TEST - 7) ? "))
plt.plot([student_1[0], 0], [student_1[1], student_1[1]], color='black', linestyle = 'dashed')
plt.plot([student_1[0], student_1[0]], [student_1[1], 0], color='black', linestyle = 'dashed')

plt.plot([student_2[0], 0], [student_2[1], student_2[1]], color='black', linestyle = 'dashed')
plt.plot([student_2[0], student_2[0]], [student_2[1], 0], color='black', linestyle = 'dashed')

num_points = 100
x = [random.uniform(1, 10) for i in range(num_points)]
y = [random.uniform(1, 10) for i in range(num_points)]
m = -2
b = 18

colors = ['green' if y[i] - m * x[i] - b > 0 else 'red' for i in range(num_points) ]

plt.scatter(x, y, c=colors)
plt.show()

# %%
plt.xlim((0, 10))
plt.ylim((0, 10))
plt.xlabel("GRADES (X2)")
plt.ylabel("TEST (X1)")
s1_plot = plt.scatter(*student_1, marker='^', color=['green'], s=100)
s2_plot = plt.scatter(*student_2, marker='^', color=['red'], s=100)
s3_plot = plt.scatter(*student_3, marker='^', color=['blue'], s=100)
plt.legend((s1_plot, s2_plot, s3_plot), ("Student 1(GRADES - 8, TEST - 9) Accepted", "Student 2(GRADES - 4, TEST - 3) Rejected", "Student 3(GRADES - 6, TEST - 7) ? "))
plt.plot([student_1[0], 0], [student_1[1], student_1[1]], color='black', linestyle = 'dashed')
plt.plot([student_1[0], student_1[0]], [student_1[1], 0], color='black', linestyle = 'dashed')

plt.plot([student_2[0], 0], [student_2[1], student_2[1]], color='black', linestyle = 'dashed')
plt.plot([student_2[0], student_2[0]], [student_2[1], 0], color='black', linestyle = 'dashed')

plt.plot([0, 10], [b, 10 * m + b], c='black')

plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# # Model
#
# ## Boundary: A Line
#
# Slope m = -2\
# x1 intercept (b) = 18\
# $$x_1 = m * x_1 + b$$
# $$x_1 = -2x_1 + 18$$
# $$2x_1 + x_2 - 18 = 0$$
# ```
# SCORE = (2 * TEST) + GRADES - 18
# ```
#  Prediction
#
# Score > 0 : **Accepted**\
# Score < 0 : **Rejected**
#
# $$w_1x_1 + w_2x_2 + b = 0$$
# $$Wx + b = 0$$
#
# $$W = (w_1, w_2)$$
# $$x = (x_1, x_2)$$
# $$y = label: 0, 1$$
# \
# \
# $$
#     \hat{y} =
# \begin{cases}
#     1,& Wx + b \geq 0\\
#     0,& Wx + b < 0\\
# \end{cases}
# $$

# %% [markdown]
# # Higher Dimension

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
point  = np.array([5, 5, 5])
normal = np.array([1, 1, 2])
xx, yy = np.meshgrid(range(10), range(10))

# a plane is a*x+b*y+c*z+d=0
# [a,b,c] is the normal. Thus, we have to calculate
# d and we're set
d = -point.dot(normal)

z = (-normal[0] * xx - normal[1] * yy - d) * 1. /normal[2]

ax.plot_surface(xx, yy, z, alpha=0.2)


x = [random.uniform(1, 10) for i in range(num_points)]
y = [random.uniform(1, 10) for i in range(num_points)]
z = [random.uniform(1, 10) for i in range(num_points)]

colors = ['green' if normal[0] * x[i] + normal[1] * y[i] + normal[2] * z[i] + d > 0 else 'red' for i in range(num_points) ]
ax.set_xlabel("GRADES (X2)")
ax.set_ylabel("TEST (X1)")
ax.set_zlabel("RANK (X3)")
ax.set_xlim((0, 10))
ax.set_ylim((0, 10))
ax.set_zlim((0, 10))

ax.scatter3D(x, y, z, c=colors );

# %% [markdown]
# ## Boundary: A Plane
#
#
# $$w_1x_1 + w_2x_2 + w_3x_3 + b = 0$$
# $$Wx + b = 0$$
#
# \
# \
# $$
#     \hat{y} =
# \begin{cases}
#     1,& Wx + b \geq 0\\
#     0,& Wx + b < 0\\
# \end{cases}
# $$
#
#
# ## n-dimentional space
#
# |           | EXAM 1 | EXAM 2 | GRADES | ... | ESSAY | Pass ? |
# |-----------|--------|--------|--------|-----|-------|--------|
# | STUDENT 1 | 9      | 6      | 5      | ... | 6     | 1(yes) |
# | STUDENT 2 | 8      | 4      | 8      | ... | 3     | 0(no)  |
# | ...       | ...    | ...    | ...    | ... | ...   | ...    |
# | STUDENT N | 6      | 7      | 2      | ... | 8     | 1(yes) |
#
# $$\text{EXAM 1 = } x_1$$
# $$\text{EXAM 2 = } x_2$$
# $$\text{GRADES = } x_3$$
# $$\text{ESSAY = } x_n$$
#
# $$w_1x_1 + w_2x_2 ... w_nx_n + b = 0$$
# $$Wx + b = 0$$
#
# \
# \
# $$
#     \hat{y} =
# \begin{cases}
#     1,& Wx + b \geq 0\\
#     0,& Wx + b < 0\\
# \end{cases}
# $$

# %% [markdown]
# **QUIZ:** Given the table, what would the dimensions be for input features (x), the weights (W), and the bias (b) to satisfy (Wx + b)?
#
#
#
# 1. W: (nx1), x: (1xn), b: (1x1)
# 2. W: (1xn), x: (1xn), b: (nx1)
# 3. W: (1xn), x: (nx1), b: (1x1)
# 4. W: (1xn), x: (nx1), b: (1xn)

# %% [markdown]
# # Perceptron
#
# ![seminar-perceptron.png](data:image/png;base64,...)

# %% [markdown]
# ![seminar-preceptron2.png](data:image/png;base64,...)

# %% [markdown]
# **QUIZ:** Given Score = 2*Test + 1*Grade - 18, suppose w1 was 1.5 instead of 2. Would the student who got 7 on the test and 6 on the grades be accepted or rejected?

# %% [markdown]
# ![preceptron-biological.png](data:image/png;base64,...)

# %% [markdown]
# # LOGICAL PERCEPTRON
#
# ![and perceptron.png](data:image/png;base64,...)
#
# | IN 1 | IN 2 | OUT |
# |------|------|-----|
# | 1    | 1    | 1   |
# | 0    | 1    | 0   |
# | 1    | 0    | 0   |
# | 0    | 0    | 0   |

# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 0.0
weight2 = 0.0
bias = 0.0


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [False, False, False, True]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))
# Out:
# You got 3 wrong.  Keep trying!
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                   0.0                    1           No
#        0          1                   0.0                    1           No
#        1          0                   0.0                    1           No
#        1          1                   0.0                    1          Yes

# %% [markdown]
# ![or perceptron.png](data:image/png;base64,...)
#
# | IN 1 | IN 2 | OUT |
# |------|------|-----|
# | 1    | 1    | 1   |
# | 0    | 1    | 1   |
# | 1    | 0    | 1   |
# | 0    | 0    | 0   |
#
# What are two ways to go from an AND perceptron to an OR perceptron?
#
# * Increase the weights
# * Decrease the weights
# * Increase single weight
# * Decrease single weight
# * Increase the magnitude of bias
# * Decrease the magnitude of bias

# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 0.0
weight2 = 0.0
bias = 0.0


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [False, True, True, True]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))
# Out:
# You got 1 wrong.  Keep trying!
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                   0.0                    1           No
#        0          1                   0.0                    1          Yes
#        1          0                   0.0                    1          Yes
#        1          1                   0.0                    1          Yes

# %% [markdown]
# # NOT Gate
#
# Only focus on Weight 2 as not gate only takes one input
#
# | IN 2 | OUT |
# |------|-----|
# | 1    | 0   |
# | 0    | 1   |

# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 0.0
weight2 = 0.0
bias = 0.0


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [True, False, True, False]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))
# Out:
# You got 2 wrong.  Keep trying!
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                   0.0                    1          Yes
#        0          1                   0.0                    1           No
#        1          0                   0.0                    1          Yes
#        1          1                   0.0                    1           No

# %% [markdown]
# # XOR Perceptron
#
# | IN 1 | IN 2 | OUT |
# |------|------|-----|
# | 1    | 1    | 0   |
# | 0    | 1    | 1   |
# | 1    | 0    | 1   |
# | 0    | 0    | 0   |
#
# ![XOR perceptron.png](data:image/png;base64,...)
#
# **Quiz** How to replace A, B and C with AND, OR, NOT to get the XOR output?

# %% [markdown]
# # Combining Perceptron

# %%
plt.xlim((0, 10))
plt.ylim((0, 10))
plt.xlabel("GRADES (X2)")
plt.ylabel("TEST (X1)")
s1_plot = plt.scatter(*student_1, marker='^', color=['green'], s=100)
s2_plot = plt.scatter(*student_2, marker='^', color=['red'], s=100)
s3_plot = plt.scatter(*student_3, marker='^', color=['blue'], s=100)
plt.legend((s1_plot, s2_plot, s3_plot), ("Student 1(GRADES - 8, TEST - 9) Accepted", "Student 2(GRADES - 4, TEST - 3) Rejected", "Student 3(GRADES - 6, TEST - 7) ? "))
plt.plot([student_1[0], 0], [student_1[1], student_1[1]], color='black', linestyle = 'dashed')
plt.plot([student_1[0], student_1[0]], [student_1[1], 0], color='black', linestyle = 'dashed')

plt.plot([student_2[0], 0], [student_2[1], student_2[1]], color='black', linestyle = 'dashed')
plt.plot([student_2[0], student_2[0]], [student_2[1], 0], color='black', linestyle = 'dashed')

plt.plot([0, 10], [b, 10 * m + b], c='black')

plt.scatter(x, y, c=colors)
plt.show()

# %%
plt.xlim((0, 10))
plt.ylim((0, 10))
plt.xlabel("GRADES (X2)")
plt.ylabel("TEST (X1)")
s1_plot = plt.scatter(*student_1, marker='^', color=['green'], s=100)
s2_plot = plt.scatter(*student_2, marker='^', color=['red'], s=100)
s3_plot = plt.scatter(*student_3, marker='^', color=['blue'], s=100)
plt.legend((s1_plot, s2_plot, s3_plot), ("Student 1(GRADES - 8, TEST - 9) Accepted", "Student 2(GRADES - 4, TEST - 3) Rejected", "Student 3(GRADES - 6, TEST - 7) ? "))
plt.plot([student_1[0], 0], [student_1[1], student_1[1]], color='black', linestyle = 'dashed')
plt.plot([student_1[0], student_1[0]], [student_1[1], 0], color='black', linestyle = 'dashed')

plt.plot([student_2[0], 0], [student_2[1], student_2[1]], color='black', linestyle = 'dashed')
plt.plot([student_2[0], student_2[0]], [student_2[1], 0], color='black', linestyle = 'dashed')



m1 = -2
b1 = 18

plt.plot([0, 10], [b1, 10 * m1 + b1], c='black')


m2 = -0.1
b2 = 4

plt.plot([0, 10], [b2, 10 * m2 + b2], c='black')

colors = ['green' if y[i] - m1 * x[i] - b1 > 0 and y[i] - m2 * x[i] - b2 > 0 else 'red' for i in range(num_points) ]

plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# # Perceptron Training
#
# 1. Start with random weights w1, w2, ... wn and random bias b
# 2. For every missclasssified points (x1, x2, ... xn)
#   1.  if predcition = 0:
#      - For i = 1..n
#         change wi + a xi
#     - change b to b + a
#   2. if predcition = 1:
#      - For i = 1..n
#         change wi - a xi
#     - change b to b - a

# %%
import numpy as np
import pandas as pd
# Setting the random seed, feel free to change it and see different solutions.
np.random.seed(42)

def stepFunction(t):
    if t >= 0:
        return 1
    return 0

def prediction(X, W, b):
    return stepFunction((np.matmul(X,W)+b)[0])

# TODO: Fill in the code below to implement the perceptron trick.
# The function should receive as inputs the data X, the labels y,
# the weights W (as an array), and the bias b,
# update the weights and bias W, b, according to the perceptron algorithm,
# and return W and b.
def perceptronStep(X, y, W, b, learn_rate = 0.01):
    # Fill in code
    return W, b
    
# This function runs the perceptron algorithm repeatedly on the dataset,
# and returns a few of the boundary lines obtained in the iterations,
# for plotting purposes.
# Feel free to play with the learning rate and the num_epochs,
# and see your results plotted below.
def trainPerceptronAlgorithm(X, y, learn_rate = 0.01, num_epochs = 25):
    x_max = max(X.T[0])
    
    W = np.array(np.random.rand(2,1))
    b = np.random.rand(1)[0] + x_max
    # These are the solution lines that get plotted below.

    boundary_lines = []
    for i in range(num_epochs):
        # In each epoch, we apply the perceptron step.
        W, b = perceptronStep(X, y, W, b, learn_rate)        
        boundary_lines.append((-W[0]/W[1], -b/W[1]))
    return boundary_lines

# %%
from matplotlib import animation
from IPython.display import HTML

df = pd.read_csv('data.csv',header=None)
X = df[[0, 1]].to_numpy()
y = df[2].to_numpy()

boundary_lines = trainPerceptronAlgorithm(X, y)

fig, ax = plt.subplots()

ax.set_xlim(( 0, 1))
ax.set_ylim((0, 1))
colors = ['green' if i == 1 else 'red' for i in y]
x1 = [x[0] for x in X ]
x2 = [x[1] for x in X ]
ax.scatter(x1, x2, c=colors)

line, = ax.plot([], [])

def animate(i):
  b_line = boundary_lines[i]
  x = [0, 1]
  y = [b_line[1], 1 * b_line[0] +  b_line[1]]
  line.set_data(x, y)
  return (line,)

anim = animation.FuncAnimation(fig, animate, frames=len(boundary_lines), repeat=False)
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="720" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# # Neural Network
#
# ![neuralnetwork.jpeg](data:image/jpeg;base64,...)

# %%
class Node(object):
    def __init__(self, inbound_nodes=[]):
        # Node(s) from which this Node receives values
        self.inbound_nodes = inbound_nodes
        # Node(s) to which this Node passes values
        self.outbound_nodes = []
        # For each inbound_node, add the current Node as an outbound_node.
        for n in self.inbound_nodes:
            n.outbound_nodes.append(self)
        # A calculated value
        self.value = None

    def forward(self):
        """
        Forward propagation.

        Compute the output value based on `inbound_nodes` and
        store the result in self.value.
        """
        raise NotImplemented

# %%
class Input(Node):
    def __init__(self):
        # An Input node has no inbound nodes,
        # so no need to pass anything to the Node instantiator.
        Node.__init__(self)

    # NOTE: Input node is the only node where the value
    # may be passed as an argument to forward().
    #
    # All other node implementations should get the value
    # of the previous node from self.inbound_nodes
    #
    # Example:
    # val0 = self.inbound_nodes[0].value
    def forward(self, value=None):
        # Overwrite the value if one is passed in.
        if value is not None:
            self.value = value

# %% [markdown]
# # Topological Sort
#
# ![topologicalsort.png](data:image/png;base64,...)
#
# function implements topological sorting using [Kahn's Algorithm](https://en.wikipedia.org/wiki/Topological_sorting#Kahn.27s_algorithm)
#
# ```
# # Define 2 `Input` nodes.
# x, y = Input(), Input()
#
# # Define an `Add` node, the two above `Input` nodes being the input.
# add = Add(x, y)
#
# # The value of `x` and `y` will be set to 10 and 20 respectively.
# feed_dict = {x: 10, y: 20}
#
# # Sort the nodes with topological sort.
# sorted_nodes = topological_sort(feed_dict=feed_dict)
# ```

# %%
def topological_sort(feed_dict):
    """
    Sort generic nodes in topological order using Kahn's Algorithm.

    `feed_dict`: A dictionary where the key is a `Input` node and the value is the respective value feed to that node.

    Returns a list of sorted nodes.
    """

    input_nodes = [n for n in feed_dict.keys()]
    
    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.outbound_nodes:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.value = feed_dict[n]

        L.append(n)
        for m in n.outbound_nodes:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            # if no other incoming edges add to S
            if len(G[m]['in']) == 0:
                S.add(m)
    return L

# %%
def forward_pass(output_node, sorted_nodes):
    """
    Performs a forward pass through a list of sorted nodes.

    Arguments:

        `output_node`: The output node of the graph (no outgoing edges).
        `sorted_nodes`: a topologically sorted list of nodes.

    Returns the output node's value
    """

    for n in sorted_nodes:
        n.forward()

    return output_node.value

# %%
class Add(Node):
    def __init__(self, x, y):
        # You could access `x` and `y` in forward with
        # self.inbound_nodes[0] (`x`) and self.inbound_nodes[1] (`y`)
        Node.__init__(self, [x, y])

    def forward(self):
        """
        Set the value of this node (`self.value`) to the sum of its inbound_nodes.
        Remember to grab the value of each inbound_node to sum!

        Your code here!
        """

# %%
x, y = Input(), Input()

f = Add(x, y)

feed_dict = {x: 10, y: 5}

sorted_nodes = topological_sort(feed_dict)
output = forward_pass(f, sorted_nodes)

# NOTE: because topological_sort sets the values for the `Input` nodes we could also access
# the value for x with x.value (same goes for y).
print("{} + {} = {} (according to miniflow)".format(feed_dict[x], feed_dict[y], output))
# Out:
# 10 + 5 = 15 (according to miniflow)

# %% [markdown]
# # Linear Node (Perceptron Node)
#
# ![perceptron_equation.png](data:image/png;base64,...)

# %%
class Linear(Node):
    def __init__(self, inputs, weights, bias):
        Node.__init__(self, [inputs, weights, bias])

        # NOTE: The weights and bias properties here are not
        # numbers, but rather references to other nodes.
        # The weight and bias values are stored within the
        # respective nodes.

    def forward(self):
        """
        Set self.value to the value of the linear function output.

        Your code goes here!
        """
        pass

# %%
inputs, weights, bias = Input(), Input(), Input()

f = Linear(inputs, weights, bias)

feed_dict = {
    inputs: [6, 14, 3],
    weights: [0.5, 0.25, 1.4],
    bias: 2
}

graph = topological_sort(feed_dict)
output = forward_pass(f, graph)

print(output)
# Out:
# 12.7

# %% [markdown]
# # 2D Data
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

class Linear(Node):
    def __init__(self, X, W, b):
        # Notice the ordering of the input nodes passed to the
        # Node constructor.
        Node.__init__(self, [X, W, b])

    def forward(self):
        """
        Set the value of this node to the linear transform output.

        Your code goes here!
        """
        pass

# %%
X, W, b = Input(), Input(), Input()

f = Linear(X, W, b)

X_ = np.array([[-1., -2.], [-1, -2]])
W_ = np.array([[2., -3], [2., -3]])
b_ = np.array([-3., -5])

feed_dict = {X: X_, W: W_, b: b_}

graph = topological_sort(feed_dict)
output = forward_pass(f, graph)

"""
Output should be:
[[-9., 4.],
[-9., 4.]]
"""
print(output)
# Out:
# None
